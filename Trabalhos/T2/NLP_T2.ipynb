# %% [markdown]
# <a href="https://colab.research.google.com/github/dudaholandah/NLP/blob/main/Trabalhos/T2/NLP_T2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# %% [markdown]
# # Pre Processing

# %%
link = "https://raw.githubusercontent.com/viniciusrpb/cic0269_natural_language_processing/main/corpus_tweets/twitter-2013train-A.txt"
df = pd.read_csv(link , sep='\t', encoding='utf-8', names = ['id', 'polarity', 'text'])

# %%
text_list = df['text']

# %% [markdown]
# ### Normalização

# %%
stopwords_nltk = stopwords.words('english')

# %%
from nltk.stem.porter import *
stemmer = PorterStemmer()

# %%
text_list_new = []
thisset = set()
emojiDict = {':)' : 'happy', '(:' : 'happy', ':(': 'sad', '):': 'sad', '(;' : 'wink', ';)' : 'wink', ':D' : 'happy', 'D:': 'sad'}
lemmatizer = nltk.stem.WordNetLemmatizer()
wn_lemmas = set(wn.all_lemma_names())

for t in text_list:
    # substituindo os emojis por palavras
    for word, initial in emojiDict.items():
      t = t.replace(word.lower(), initial)
    
    # regex para tirar caracteres, numeros, upcode e links htpp
    words = re.sub(r'[\s!%*~\^´`=+<\[\]?&$:;@#.0-9()\/\"\'_-]+|[\s]*[\\]u[a-z0-9]{4}[\s]*|[\s]*http[^\s]+[\s]*', " ", t.lower())
    words = re.sub(r'\brt\b', "", words)
    words = re.sub(r'[\\]+', " ", words)
    words = words.strip()
    
    phrase = ""
    words = words.split()

    # tirando stopwords
    # colocando apenas as palavras que estao na gramatica wordnet
    # fazendo stematizacao
    for x in words:
        if x not in stopwords_nltk and x in wn_lemmas:
            x = stemmer.stem(x)
            thisset.add(x)
            phrase = phrase + " " + x
        

    text_list_new.append(phrase.strip())

# %%
thisset #Vocabulario de todos os tweets
# Out:
# {'lemonad',
#  'traine',
#  'rebu',
#  'fold',
#  'venu',
#  'zap',
#  'river',
#  'patienc',
#  'woo',
#  'racism',
#  'bantam',
#  'awkward',
#  'shakeout',
#  'stubborn',
#  'move',
#  'offer',
#  'assign',
#  'kami',
#  'slug',
#  'prissi',
#  'groceri',
#  'aesthet',
#  'blacksburg',
#  'lesson',
#  'superior',
#  'fastest',
#  'yay',
#  'rapper',
#  'time',
#  'dude',
#  'haley',
#  'wit',
#  'nutrient',
#  'victim',
#  'eugenia',
#  'nazi',
#  'mono',
#  'v',
#  'mob',
#  'maya',
#  'crispi',
#  'recip',
#  'catherin',
#  'steam',
#  'dark',
#  'joewood',
#  'cheeri',
#  'foundat',
#  'mountain',
#  'chart',
#  'halftim',
#  'emce',
#  'accomplish',
#  'payday',
#  'brownsvil',
#  'robberi',
#  'mani',
#  'big',
#  'argentin',
#  'entitl',
#  'ipo',
#  'grand',
#  'wrangler',
#  'architect',
#  'santiago',
#  'plan',
#  'isl',
#  'prayer',
#  'intuit',
#  'healthier',
#  'interfac',
#  'oxygen',
#  'takin',
#  'latt',
#  'rant',
#  'tender',
#  'cast',
#  'telli',
#  'promin',
#  'baptist',
#  'bowl',
#  'oyster',
#  'debt',
#  'racket',
#  'southbound',
#  'suprem',
#  'ipod',
#  'pride',
#  'helicopt',
#  'vale',
#  'kid',
#  'loner',
#  'sam',
#  'header',
#  'bend',
#  'blimp',
#  'wesley',
#  'politico',
#  'mediocr',
#  'gentli',
#  'grader',
#  'ad',
#  'shakeup',
#  'payment',
#  'goos',
#  'conquest',
#  'rubi',
#  'mauler',
#  'sojourn',
#  'dirk',
#  'skinner',
#  'castaway',
#  'breweri',
#  'environment',
#  'director',
#  'knee',
#  'burn',
#  'marti',
#  'trial',
#  'offens',
#  'marin',
#  'germ',
#  'earli',
#  'transpar',
#  'limit',
#  'volleybal',
#  'editori',
#  'cent',
#  'recreat',
#  'disco',
#  'flat',
#  'ramp',
#  'grossli',
#  'tnt',
#  'stump',
#  'ecuadorian',
#  'tremend',
#  'mile',
#  'bosh',
#  'liar',
#  'wine',
#  'barrymor',
#  'planet',
#  'luci',
#  'appleton',
#  'cuss',
#  'apt',
#  'iran',
#  'newscast',
#  'ted',
#  'gaza',
#  'gap',
#  'azerbaijan',
#  'soundtrack',
#  'haw',
#  'sax',
#  'gibson',
#  'knight',
#  'hacker',
#  'distract',
#  'iranian',
#  'pee',
#  'serbian',
#  'salvat',
#  'armenian',
#  'milwauke',
#  'flop',
#  'hank',
#  'halcyon',
#  'planner',
#  'su',
#  'vigor',
#  'truant',
#  'pretzel',
#  'trek',
#  'intens',
#  'ba',
#  'mannheim',
#  'edward',
#  'lux',
#  'nois',
#  'neg',
#  'sesam',
#  'primer',
#  'cafeteria',
#  'epi',
#  'darn',
#  'audio',
#  'union',
#  'buffet',
#  'class',
#  'behaviour',
#  'rerun',
#  'ron',
#  'fun',
#  'silver',
#  'spiral',
#  'carbon',
#  'sip',
#  'starv',
#  'bronx',
#  'swamp',
#  'thin',
#  'ten',
#  'attent',
#  'edwin',
#  'mate',
#  'cold',
#  'nra',
#  'peru',
#  'asham',
#  'coastal',
#  'joke',
#  'ballot',
#  'ponc',
#  'slide',
#  'fright',
#  'boredom',
#  'dart',
#  'depot',
#  'jumpstart',
#  'j',
#  'lb',
#  'moodi',
#  'qatar',
#  'amount',
#  'desk',
#  'seth',
#  'wow',
#  'decad',
#  'bottom',
#  'havoc',
#  'chandler',
#  'mesa',
#  'laugh',
#  'scrub',
#  'addit',
#  'finger',
#  'slow',
#  'alarm',
#  'payrol',
#  'reckon',
#  'blind',
#  'fundrais',
#  'rebound',
#  'caravan',
#  'extravaganza',
#  'braga',
#  'summit',
#  'wheel',
#  'cupid',
#  'prelim',
#  'recap',
#  'ivi',
#  'servic',
#  'era',
#  'jupit',
#  'guilt',
#  'banger',
#  'come',
#  'imperson',
#  'emerg',
#  'leicestershir',
#  'hardli',
#  'trio',
#  'sent',
#  'mol',
#  'grad',
#  'heavili',
#  'niner',
#  'pix',
#  'meme',
#  'latter',
#  'outlandish',
#  'indonesia',
#  'ayah',
#  'achiev',
#  'sober',
#  'fastbal',
#  'jerusalem',
#  'ara',
#  'wale',
#  'moor',
#  'regist',
#  'teen',
#  'simultan',
#  'real',
#  'ks',
#  'deliveri',
#  'nga',
#  'household',
#  'tomato',
#  'sousa',
#  'secretari',
#  'md',
#  'springer',
#  'bound',
#  'bar',
#  'embarrass',
#  'hurrican',
#  'cleanup',
#  'theori',
#  'revis',
#  'horror',
#  'suspect',
#  'collect',
#  'lesser',
#  'commiss',
#  'cloud',
#  'similar',
#  'grind',
#  'regret',
#  'lakeland',
#  'indi',
#  'icecream',
#  'center',
#  'wichita',
#  'fp',
#  'timelin',
#  'herald',
#  'kinship',
#  'constitut',
#  'mei',
#  'properli',
#  'luau',
#  'jerri',
#  'maldivian',
#  'alli',
#  'richardson',
#  'equival',
#  'phoenix',
#  'taxi',
#  'pink',
#  'ka',
#  'recit',
#  'pluck',
#  'unchang',
#  'champ',
#  'disappoint',
#  'tech',
#  'camp',
#  'deepli',
#  'nc',
#  'pathet',
#  'subway',
#  'morgan',
#  'argu',
#  'field',
#  'faint',
#  'wave',
#  'calendar',
#  'fourteen',
#  'home',
#  'manual',
#  'aerial',
#  'gibb',
#  'vice',
#  'aztec',
#  'turner',
#  'lettuc',
#  'unload',
#  'browser',
#  'pull',
#  'overjoy',
#  'revert',
#  'atmospher',
#  'keller',
#  'point',
#  'capabl',
#  'crimson',
#  'flex',
#  'sac',
#  'edgar',
#  'decid',
#  'beyond',
#  'landlord',
#  'utrecht',
#  'versatil',
#  'stock',
#  'breakdown',
#  'loot',
#  'construct',
#  'blowout',
#  'ii',
#  'confidenti',
#  'tell',
#  'suppli',
#  'replay',
#  'heard',
#  'vanessa',
#  'stuff',
#  'dugout',
#  'accessori',
#  'favour',
#  'sa',
#  'sacramento',
#  'crash',
#  'longest',
#  'oppos',
#  'rg',
#  'cross',
#  'rub',
#  'labyrinth',
#  'colour',
#  'shelter',
#  'homeroom',
#  'knoxvil',
#  'involv',
#  'danc',
#  'ungraci',
#  'grung',
#  'lynchburg',
#  'charact',
#  'wizard',
#  'dunk',
#  'standard',
#  'reset',
#  'congratul',
#  'troublemak',
#  'lightweight',
#  'icu',
#  'clari',
#  'chronicl',
#  'bo',
#  'frighten',
#  'dozer',
#  'pinter',
#  'brick',
#  'yangtz',
#  'skater',
#  'caraway',
#  'japanes',
#  'amigo',
#  'higher',
#  'elvi',
#  'fall',
#  'limerick',
#  'everi',
#  'nw',
#  'fellow',
#  'brazilian',
#  'yorkshir',
#  'condit',
#  'work',
#  'backward',
#  'scummi',
#  'untold',
#  'shout',
#  'sagittariu',
#  'smyrna',
#  'electron',
#  'speak',
#  'dock',
#  'page',
#  'cradl',
#  'trend',
#  'flashback',
#  'fl',
#  'interior',
#  'pronounc',
#  'child',
#  'neon',
#  'ab',
#  'idl',
#  'shack',
#  'chevi',
#  'palestinian',
#  'instal',
#  'deaf',
#  'clitori',
#  'stanley',
#  'morocco',
#  'australian',
#  'gulf',
#  'frozen',
#  'branch',
#  'scream',
#  'puppi',
#  'solid',
#  'honest',
#  'curv',
#  'beirut',
#  'storylin',
#  'bollock',
#  'mom',
#  'kicker',
#  'immun',
#  'tue',
#  'friday',
#  'speaker',
#  'al',
#  'cabinet',
#  'vista',
#  'phone',
#  'theatr',
#  'ballroom',
#  'belat',
#  'poster',
#  'urgent',
#  'better',
#  'allianc',
#  'ur',
#  'strictli',
#  'provis',
#  'chap',
#  'rockwel',
#  'armada',
#  'address',
#  'brent',
#  'thigh',
#  'lab',
#  'level',
#  'will',
#  'mush',
#  'engag',
#  'stephenson',
#  'portray',
#  'balanc',
#  'triumph',
#  'abc',
#  'tomorrow',
#  'peacock',
#  'unoffici',
#  'directli',
#  'cardboard',
#  'irish',
#  'disgrac',
#  'afl',
#  'slum',
#  'start',
#  'respect',
#  'arabian',
#  'roman',
#  'brink',
#  'eye',
#  'rebat',
#  'chin',
#  'shelley',
#  'furnitur',
#  'thread',
#  'survivor',
#  'corker',
#  'gesel',
#  'halo',
#  'suspens',
#  'domingo',
#  'princ',
#  'titan',
#  'vatican',
#  'harrow',
#  'hapless',
#  'binder',
#  'love',
#  'fab',
#  'tin',
#  'eddi',
#  'burma',
#  'held',
#  'coy',
#  'glass',
#  'roundhous',
#  'broken',
#  'bale',
#  'loud',
#  'preseason',
#  'staff',
#  'ano',
#  'dislik',
#  'berlin',
#  'tough',
#  'sheet',
#  'cave',
#  'ration',
#  'common',
#  'esteem',
#  'laundri',
#  'rome',
#  'odysseu',
#  'curri',
#  'heaven',
#  'tagalog',
#  'montreal',
#  'origin',
#  'pool',
#  'benghazi',
#  'hoya',
#  'appal',
#  'odessa',
#  'ward',
#  'napoli',
#  'singer',
#  'trap',
#  'fiji',
#  'rex',
#  'ms',
#  'dice',
#  'goddard',
#  'blackout',
#  'arena',
#  'poor',
#  'ox',
#  'prevail',
#  'panel',
#  'distast',
#  'delhi',
#  'advis',
#  'osborn',
#  'dispatch',
#  'smiley',
#  'technologist',
#  'rebuild',
#  'card',
#  'moment',
#  'practic',
#  'fals',
#  'lutheran',
#  'noth',
#  'posh',
#  'popular',
#  'botch',
#  'fee',
#  'eclips',
#  'meatbal',
#  'directori',
#  'cheesi',
#  'upsid',
#  'option',
#  'wicker',
#  'teenag',
#  'allegedli',
#  'foreign',
#  'aesop',
#  'cutler',
#  'ne',
#  'univers',
#  'canada',
#  'immov',
#  'babe',
#  'photographi',
#  'particip',
#  'robot',
#  'jake',
#  'struggl',
#  'jealou',
#  'fanci',
#  'dimens',
#  'oral',
#  'hatr',
#  'hammer',
#  'multimedia',
#  'complac',
#  'laguna',
#  'ohio',
#  'behav',
#  'mansion',
#  'tee',
#  'warehous',
#  'graveyard',
#  'run',
#  'duplex',
#  'hs',
#  'appli',
#  'pepsi',
#  'servant',
#  'stewart',
#  'tam',
#  'west',
#  'bazaar',
#  'thirsti',
#  'faggot',
#  'unfortun',
#  'navi',
#  'shrimp',
#  'nanci',
#  'romant',
#  'afghan',
#  'mascot',
#  'sound',
#  'tast',
#  'rachel',
#  'gaswork',
#  'lawless',
#  'furiou',
#  'facil',
#  'peski',
#  'bridg',
#  'roger',
#  'excess',
#  'trainer',
#  'infrar',
#  'surrey',
#  'martin',
#  'sniff',
#  'letterman',
#  'actress',
#  'stick',
#  'sen',
#  'scene',
#  'close',
#  'futurist',
#  'whop',
#  'zombi',
#  'occasion',
#  'decim',
#  'high',
#  'thu',
#  'newport',
#  'coliseum',
#  'counter',
#  'furi',
#  'hike',
#  'string',
#  'grappl',
#  'col',
#  'dig',
#  'holstein',
#  'doom',
#  'topeka',
#  'intim',
#  'ciao',
#  'fort',
#  'grandpa',
#  'replac',
#  'obvious',
#  'malaysia',
#  'wall',
#  'sparkleberri',
#  'wafer',
#  'seem',
#  'hamper',
#  'punch',
#  'plaza',
#  'liquidambar',
#  'cactu',
#  'jacob',
#  'ignit',
#  'robin',
#  'languag',
#  'salvador',
#  'monterey',
#  'oman',
#  'proof',
#  'confirm',
#  'splitsvil',
#  'net',
#  'lore',
#  'firefli',
#  'decor',
#  'meredith',
#  'typic',
#  'clash',
#  'li',
#  'pope',
#  'frobish',
#  'illumin',
#  'strateg',
#  'med',
#  'creepi',
#  'trust',
#  'amor',
#  'heel',
#  'back',
#  'akron',
#  'list',
#  'garter',
#  'deep',
#  'quid',
#  'featur',
#  'nectar',
#  'lego',
#  'rivera',
#  'cambridg',
#  'brook',
#  'build',
#  'butterfli',
#  'must',
#  'razzmatazz',
#  'entri',
#  'roll',
#  'tic',
#  'hunter',
#  'dive',
#  'keeper',
#  'australia',
#  'alway',
#  'mongoos',
#  'joint',
#  'taken',
#  'telephon',
#  'color',
#  'empir',
#  'strikeout',
#  'ongo',
#  'northeast',
#  'problem',
#  'margat',
#  'fig',
#  'lake',
#  'suddenli',
#  'unread',
#  'veteran',
#  'cuba',
#  'gari',
#  'highschool',
#  'adapt',
#  'global',
#  'bunker',
#  'awar',
#  'upright',
#  'guarante',
#  'stickbal',
#  'scorch',
#  'migrat',
#  'asid',
#  'tux',
#  'madra',
#  'alzheim',
#  'swarm',
#  'gat',
#  'yet',
#  'abraham',
#  'domin',
#  'twin',
#  'trump',
#  'shell',
#  'dead',
#  'socialist',
#  'funki',
#  'verona',
#  'grown',
#  'virtuou',
#  'good',
#  'half',
#  'goa',
#  'contain',
#  'roller',
#  'flyer',
#  'mistress',
#  'granni',
#  'today',
#  'hitman',
#  'trivia',
#  'maroon',
#  'plain',
#  'cozi',
#  'mighti',
#  'andrew',
#  'girl',
#  'custard',
#  'jumbo',
#  'artemi',
#  'meanwhil',
#  'genuin',
#  'victor',
#  'throw',
#  'flash',
#  'bratwurst',
#  'teacher',
#  'loan',
#  'yi',
#  'plane',
#  'neapolitan',
#  'wire',
#  'harmoni',
#  'sauna',
#  'truck',
#  'incheon',
#  'one',
#  'vietnam',
#  'bounci',
#  'educ',
#  'tia',
#  'au',
#  'novel',
#  'ordinari',
#  'bee',
#  'claus',
#  'facad',
#  'bradi',
#  'outrag',
#  'psychosi',
#  'circumst',
#  'iron',
#  'bunt',
#  'lebanes',
#  'wimp',
#  'resist',
#  'jonathan',
#  'human',
#  'weav',
#  'wipeout',
#  'matrimoni',
#  'pursu',
#  'onstag',
#  'bartlett',
#  'deriv',
#  'yanke',
#  'somalia',
#  'alert',
#  'round',
#  'manufactur',
#  'xhosa',
#  'reagan',
#  'fuck',
#  'heartbreak',
#  'honkytonk',
#  'roommat',
#  'fantasi',
#  'nj',
#  'iditarod',
#  'trail',
#  'taipei',
#  'backyard',
#  'calif',
#  'brooklyn',
#  'itali',
#  'scholarship',
#  'throwback',
#  'academ',
#  'underwat',
#  'hipster',
#  'cream',
#  'sampl',
#  'yellow',
#  'fourth',
#  'porno',
#  'prosecutor',
#  'albani',
#  'despis',
#  'specul',
#  'dalla',
#  'infidel',
#  'trebl',
#  'stash',
#  'name',
#  'sneaker',
#  'addict',
#  'jr',
#  'ky',
#  'declar',
#  'hurdl',
#  'calcul',
#  'sucker',
#  'primu',
#  'moscow',
#  'jean',
#  'casino',
#  'bleach',
#  'nimitz',
#  'amaz',
#  'inc',
#  'pointless',
#  'rapaci',
#  'audienc',
#  'recept',
#  'regim',
#  'tammi',
#  'everywher',
#  'trad',
#  'magic',
#  'chemic',
#  'offshoot',
#  'somerset',
#  'jimmi',
#  'mak',
#  'resid',
#  'pick',
#  'raft',
#  'bug',
#  'hitch',
#  'shootout',
#  'unbow',
#  'hound',
#  'spielberg',
#  'ach',
#  'uca',
#  'dracula',
#  'chuck',
#  'spoof',
#  'chair',
#  'silk',
#  'paella',
#  'raini',
#  'hargeisa',
#  'lash',
#  'analysi',
#  'neck',
#  'auror',
#  'amp',
#  'plate',
#  'south',
#  'salem',
#  'hallway',
#  'bullock',
#  'expect',
#  'reunit',
#  'inspect',
#  'superstiti',
#  'paper',
#  'outsid',
#  ...}

# %%
df['text'] = text_list_new

df #Impressão do Dataframe de tweets
# Out:
#                       id  polarity  \
# 0     264183816548130816  positive
# 1     263405084770172928  negative
# 2     262163168678248449  negative
# 3     264249301910310912  negative
# 4     262682041215234048   neutral
# ...                  ...       ...
# 9679  103158179306807296  positive
# 9680  103157324096618497  positive
# 9681  100259220338905089   neutral
# 9682  104230318525001729  positive
# 9683  100461938533863424  negative
#
#                                                    text
# 0                  ga hous hit go chapel hill sat happi
# 1                 still shit watch johnni deal saturday
# 2                      fan hate nick diaz wait februari
# 3     iranian gener israel iron dome deal keep talk ...
# 4              tehran mon amour tri establish vote mitt
# ...                                                 ...
# 9679      monday monday night footbal mind love footbal
# 9680  know road start tonight set record season guar...
# 9681  blue white r meet golden corral dinner tonight pm
# 9682                       great game tampa bay tonight
# 9683                  miss kid show worldwid hear posit
#
# [9684 rows x 3 columns]
